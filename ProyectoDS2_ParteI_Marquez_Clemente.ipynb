# %% [markdown]
# <a href="https://colab.research.google.com/github/1ncl3m3nt3/Comision-61175-Clemente-Marquez/blob/main/ProyectoDS2_ParteI_Marquez_Clemente.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Proyecto Final - Primera Entrega**

# %% [markdown]
# *   **Curso:** Data Science II: Machine Learning para la Ciencia de Datos
# *   **Comisión:** 61175
# *   **Autor:** Clemente Elías Márquez Alvíarez
# *   **Tema:** Modelo de Predicción del Precio de Vehículos Usados
# *   **Dataset:** autos.csv

# %% [markdown]
# ## **Presentación del proyecto**

# %% [markdown]
# Modelo de Predicción del Precio de Vehículos Usados

# %% [markdown]
# ![autos-usados-5.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **Motivación y Audiencia**

# %% [markdown]
# Actualmente el mercado de autos usados en todo el mundo está creciendo rápidamente, se espera que este logre alcanzar los 284 mil millones de dólares para el 2030, lo que representa un incremento de casi el 8% anual con respecto al 2021. La razón principal de esto ha sido la inclusión de empresas organizadas en el mercado de los países en desarrollo, que se han encargado de reducir el déficit de confianza que existía en el mercado de autos usados  durante años. Otra razón de suma importancia es la creciente digitalización y la capacidad de las empresas para brindar experiencias de compras inmersivas de forma remota, generando un valor agregado para la experiencia tanto de compradores como de vendedores de este rubro.

# %% [markdown]
# Otros factores de este incremento son el aumento de proveedores financieros que ofrecen créditos para autos usados, el aumento de los niveles de ingresos, el aumento de la demanda de automóviles de lujo, períodos de propiedad de automóviles más cortos y una preferencia cada vez mayor por parte de los propietarios de vehículos de dos ruedas para actualizarse a automóviles pequeños y compactos impulsan el crecimiento del mercado.

# %% [markdown]
# Con el crecimiento gradual del sector organizado de ventas de vehículos usados, la situación del mercado está cambiando y los principales actores, como Toyota, BMW, Maruti, Suzuki, etc., se han aventurado en esta área de negocio en diversas partes del mundo.

# %% [markdown]
# Con la creciente tendencia en tecnología, la compra de vehículos usados a través de ventas en línea se ha convertido en la opción preferida por los clientes en los últimos años. Las empresas nuevas compiten con los jugadores existentes brindando servicios personalizados, una nueva flota y una estrategia de precios bajos. En el mercado norteamericano, donde la relación entre la venta de autos usados y la venta de autos nuevos es de casi 2 a 1, con esto es necesario un elemento diferenciador entre las principales empresas que ofrecen este servicio, para esto muchos jugadores nuevos están aprovechando la inteligencia artificial y el análisis de Big Data para diferenciar su marca y sus ofertas de los concesionarios de autos usados convencionales.

# %% [markdown]
# Mencionado todo esto, se genera el interés de desarrollar una herramienta de data science que permita predecir el valor de mercado de un auto usado teniendo en cuenta algunas de las características de este; el modelo estaría dirigido para el personal operativo de la empresa y para el desarrollo de aplicativos o servicios web que permitan tasar el precio de un auto usado sin la necesidad de ser revisado por un perito, de esta forma se pueden obtener beneficios tanto para los clientes externos agilizando y  mejorando considerablemente la experiencia de venta, acelerando la transacción y para la empresa vendedora con la disminución de horas de trabajo o personal especializado para revisar y tasar vehículos que muchas veces no terminan siendo adquiridos por la empresa.

# %% [markdown]
# ### **Contexto Analitico y Dataset**

# %% [markdown]
# El dataset seleccionado contiene 19.237 muestras, cada una de las cuales representa un automóvil usado, estos se dividen en 18 columnas con variables cuantitativas y variables cualitativas, con una columna objetivo que refleja el valor de venta del auto, basándose en valoraciones realistas observadas en transacciones de autos usados.

# %% [markdown]
# Con esta información se busca tener una visión integral de los factores que influyen en la valoración del precio de los autos usados, entre estos podemos destacar las siguientes categorías:
# * Datos Fabricante: fabricante, modelo, categoría y año de producción.
# * Datos Técnicos: tipo de combustible, volumen del motor, cantidad de cilindros, tipo de transmisión, tipo de tracción, ubicación del volante y cantidad de airbags.
# * Datos Estéticos: Interior de cuero, cantidad de puertas y color.
# * Datos de Uso: Kilometraje
# * Datos Financieros: Precio e Impuesto.

# %% [markdown]
# ### **Fuente**

# %% [markdown]
# [https://www.kaggle.com/datasets/deepcontractor/car-price-prediction-challenge](https://www.kaggle.com/datasets/deepcontractor/car-price-prediction-challenge)

# %% [markdown]
# ### **Hipótesis**

# %% [markdown]
# Con toda esta información se busca identificar la relación de cada uno de estos factores con la valoración final del precio de un automóvil. Una vez contemos con este análisis nos gustaría poder responder las siguientes preguntas:
# *   Cual de las categorías antes mencionadas (datos de fabricante, datos técnicos, datos estéticos o datos de uso) tiene mayor efecto en el incremento de la valoración del auto usado?
# *   Esta relación se mantiene en los principales fabricantes o cada uno de estos tiene sus propios factores de incremento de la valoración del precio?
# *   Una persona puede tener en consideraciones ciertos factores técnicos y estéticos al adquirir un automóvil para poder obtener el mayor valor de reventa?

# %% [markdown]
# ### **Objetivo**

# %% [markdown]
# El objetivo del proyecto es desarrollar un modelo de data science que pueda predecir el valor de venta de un automóvil usado basándose en diversas características. Para lograr esto, usaremos diversos algoritmos, para poder comparar la efectividad de cada uno de ellos e inclinarnos por el que genere los mejores resultados en la predicción.

# %% [markdown]
# ## **Lectura de datos**

# %% [markdown]
# ### **Librerías necesarias para el análisis de datos**

# %%
#Importar librerias
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

#Escoger el tipo de tema para los gráficos
sns.set_theme(style="whitegrid")

# %% [markdown]
# ### **Lectura del dataset**

# %%
#Carga Dataset
url = "https://raw.githubusercontent.com/1ncl3m3nt3/Comision-61175-Clemente-Marquez/refs/heads/main/Datasets/Vehiculos/autos.csv"
dataset = pd.read_csv(url)
dataset
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %% [markdown]
# ### **Análisis inicial del dataset**

# %%
#Informacion de Dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
# ...

# %% [markdown]
# Diccionarios de las columnas
# - ID: número de identificación del automóvil
# - Price: valoración en dólares del automóvil. **(Variable Objetivo)**
# - Levy: impuesto del automóvil.
# - Manufacturer: fabricante del automóvil.
# - Model: modelo del automóvil.
# - Prod. Year: año de producción del automóvil.
# -  Category: categoría del tipo del automóvil.
# - Leather Interior: tapizado de cuero en el automóvil.
# - Fuel Type: tipo de combustible del automóvil.
# - Engine Volume: volumen del motor del automóvil.
# - Mileage: kilometraje de uso del automóvil.
# - Cylinders: cantidad de cilindros del motor del automóvil.
# - Gear Box Type: tipo de transmisión del automóvil.
# - Drive Wheels: tipo de tracción del automóvil.
# - Doors: cantidad de puertas del automóvil.
# - Wheel: posición de volante del automóvil.
# - Color: color del automóvil.
# - Airbags: cantidad de bolsas de aire del automóvil.

# %%
#Tipos de variables
dataset.dtypes.value_counts()
# Out:
# object     13
# int64       4
# float64     1
# Name: count, dtype: int64

# %%
#Tamaño del dataset KB
dataset.size
# Out:
# 346266

# %%
#Forma del dataset
dataset.shape
# Out:
# (19237, 18)

# %%
#Descripción de las variables cuantitativas
dataset.describe().T
# Out:
#               count          mean            std         min         25%  \
# ID          19237.0  4.557654e+07  936591.422799  20746880.0  45698374.0
# Price       19237.0  1.855593e+04  190581.269684         1.0      5331.0
# Prod. year  19237.0  2.010913e+03       5.668673      1939.0      2009.0
# Cylinders   19237.0  4.582991e+00       1.199933         1.0         4.0
# Airbags     19237.0  6.582627e+00       4.320168         0.0         4.0
#
#                    50%         75%         max
# ID          45772308.0  45802036.0  45816654.0
# Price          13172.0     22075.0  26307500.0
# Prod. year      2012.0      2015.0      2020.0
# Cylinders          4.0         4.0        16.0
# Airbags            6.0        12.0        16.0

# %%
#Descripción de las variables cualitativas
dataset.describe(include=['object']).T
# Out:
#                   count unique         top   freq
# Levy              19237    559           -   5819
# Manufacturer      19237     65     HYUNDAI   3769
# Model             19237   1590       Prius   1083
# Category          19237     11       Sedan   8736
# Leather interior  19237      2         Yes  13954
# Fuel type         19237      7      Petrol  10150
# Engine volume     19237    107           2   3916
# Mileage           19237   7687        0 km    721
# Gear box type     19237      4   Automatic  13514
# Drive wheels      19237      3       Front  12874
# Doors             19237      3      04-May  18332
# Wheel             19237      2  Left wheel  17753
# Color             19237     16       Black   5033

# %% [markdown]
# ## **Data Wrangling: Limpieza y transformación de datos**

# %% [markdown]
# ### **Valores duplicados**

# %%
#Total de valores duplicados
dataset.duplicated().sum()
# Out:
# 313

# %% [markdown]
# Examinamos el dataset para ver la cantidad de valores duplicados.

# %%
#Valores duplicados
duplicate_rows = dataset[dataset.duplicated()]
duplicate_rows
# Out:
#              ID  Price  Levy   Manufacturer        Model  Prod. year  \
# 425    45815372   7840     -  MERCEDES-BENZ        E 200        1998
# 1581   45815363   8781     -         TOYOTA          Ist        2002
# 1697   45732125  18503     -         TOYOTA        Prius        2010
# 1972   45507765  20385     -  MERCEDES-BENZ      CLS 500        2005
# 2131   45815363   8781     -         TOYOTA          Ist        2002
# ...         ...    ...   ...            ...          ...         ...
# 18974  45815465   2352  1273          LEXUS       IS 350        2015
# 19137  45810466  15125   642      CHEVROLET      Orlando        2012
# 19200  45725908  36065   640  MERCEDES-BENZ  CLA 250 AMG        2013
# 19203  45761487  13485   645         TOYOTA        Prius        2011
# 19210  45732939   8311   642        HYUNDAI       Sonata        2012
#
#         Category Leather interior Fuel type Engine volume    Mileage  \
# ...

# %% [markdown]
# *Identificamos los valores duplicados.*

# %%
#Eliminar valores duplicados
dataset = dataset.drop_duplicates()
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# *Eliminamos los valores duplicados.*

# %%
#Informacion de Dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18924 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18924 non-null  int64
#  1   Price             18924 non-null  int64
#  2   Levy              18924 non-null  object
#  3   Manufacturer      18924 non-null  object
#  4   Model             18924 non-null  object
#  5   Prod. year        18924 non-null  int64
#  6   Category          18924 non-null  object
#  7   Leather interior  18924 non-null  object
#  8   Fuel type         18924 non-null  object
#  9   Engine volume     18924 non-null  object
#  10  Mileage           18924 non-null  object
#  11  Cylinders         18924 non-null  float64
#  12  Gear box type     18924 non-null  object
#  13  Drive wheels      18924 non-null  object
#  14  Doors             18924 non-null  object
#  15  Wheel             18924 non-null  object
# ...

# %% [markdown]
# ### **Valores nulos**

# %%
#Valores nulos
dataset.isnull().sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %% [markdown]
# *Examinamos el dataset para ver la cantidad de valores nulos, dado que no hay de estos no es necesario tomar ninguna medida de correción.*

# %% [markdown]
# ### **Transformaciones de variables y/o valores**

# %%
#Chequeo de la cantidad de valores unicos
for col in dataset.columns:
    print(f'Cantidad de unicos en {col} son :{len(dataset[col].unique())}')
# Out:
# Cantidad de unicos en Price son :2315
# Cantidad de unicos en Levy son :559
# Cantidad de unicos en Manufacturer son :65
# Cantidad de unicos en Model son :1590
# Cantidad de unicos en Prod. year son :54
# Cantidad de unicos en Category son :11
# Cantidad de unicos en Leather interior son :2
# Cantidad de unicos en Fuel type son :7
# Cantidad de unicos en Engine volume son :65
# Cantidad de unicos en Mileage son :7687
# Cantidad de unicos en Cylinders son :13
# Cantidad de unicos en Gear box type son :4
# Cantidad de unicos en Drive wheels son :3
# Cantidad de unicos en Doors son :3
# Cantidad de unicos en Wheel son :2
# Cantidad de unicos en Color son :16
# Cantidad de unicos en Airbags son :17
# Cantidad de unicos en Turbo son :2
# Cantidad de unicos en Age son :54

# %%
#Chequeo de los valores unicos
for col in dataset.columns:
    print(f'Categorias en {col} son :\n {dataset[col].unique()}\n')
# Out:
# Categorias en Price son :
#  [13328 16621  8467 ... 56814 63886 22075]
#
# Categorias en Levy son :
#  [ 1399  1018     0   862   446   891   761   751   394  1053  1055  1079
#    810  2386  1850   531   586  1249  2455   583  1537  1288   915  1750
#    707  1077  1486  1091   650   382  1436  1194   503  1017  1104   639
#    629   919   781   530   640   765   777   779   934   769   645  1185
#   1324   830  1187  1111   760   642  1604  1095   966   473  1138  1811
#    988   917  1156   687 11714   836  1347  2866  1646   259   609   697
#    585   475   690   308  1823  1361  1273   924   584  2078   831  1172
#    893  1872  1885  1266   447  2148  1730   730   289   502   333  1325
#    247   879  1342  1327  1598  1514  1058   738  1935   481  1522  1282
#    456   880   900   798  1277   442  1051   790  1292  1047   528  1211
#   1493  1793   574   930  1998   271   706  1481  1677  1661  1286  1408
# ...

# %% [markdown]
# *Examinamos el dataset para ver los valores unicos de las variables e identificar si es necesario aplicar algunos cambios o hace alguna correción.*

# %%
# Correccion de la variable Levy
# Reemplazo de '-' with 0
dataset['Levy']=dataset['Levy'].replace('-','0')
# Convertir Levy a int
dataset['Levy'] = dataset['Levy'].astype('int64')
dataset['Levy']
# Out:
# <ipython-input-16-b1fd1cb8824b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Levy']=dataset['Levy'].replace('-','0')
# <ipython-input-16-b1fd1cb8824b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Levy'] = dataset['Levy'].astype('int64')
# 0        1399
# 1        1018
# 2           0
# 3         862
# 4         446
#          ...
# 19232       0
# 19233     831
# 19234     836
# 19235    1288
# 19236     753
# Name: Levy, Length: 18924, dtype: int64

# %% [markdown]
# *La variable Levy tienes algunos valores con "-" los cuales vamos a reemplazar con el valor 0, definimos la variable como entero.*

# %%
# Correccion de la variable Engine volume
# Normalizamos a minuscula la palabra turbo
dataset['Engine volume'] = dataset['Engine volume'].str.lower()
# Ubicamos las columnas donde indican la version turbo y generamos una nueva columna
dataset['Turbo'] = dataset['Engine volume'].str.contains('turbo')
# Remplazo de la palabra 'Turbo' with ''
dataset['Engine volume'] = dataset['Engine volume'].str.replace('turbo','')
# Converting Engine volume a float
dataset['Engine volume'] = dataset['Engine volume'].astype('float64')
dataset[['Engine volume', 'Turbo']]
# Out:
# <ipython-input-17-8e1db35e1ac6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Engine volume'] = dataset['Engine volume'].str.lower()
# <ipython-input-17-8e1db35e1ac6>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Turbo'] = dataset['Engine volume'].str.contains('turbo')
# <ipython-input-17-8e1db35e1ac6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# *La variable Engine volume contiene algunos casos la indicacion de modelo turbo, en este caso creamos una nueva columna de variable boleana para indicar si es version turbo o no, luego eliminamos la palabra turbo y transformamos la variable en flotante.*

# %%
# Correccion de la variable Mileage
# Eliminar la palabra'Km'
dataset['Mileage'] = dataset['Mileage'].str.strip('km')
# Convertir Mileage a int
dataset['Mileage'] = dataset['Mileage'].astype('int64')
dataset['Mileage']
# Out:
# <ipython-input-18-19ec217941ba>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Mileage'] = dataset['Mileage'].str.strip('km')
# <ipython-input-18-19ec217941ba>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Mileage'] = dataset['Mileage'].astype('int64')
# 0        186005
# 1        192000
# 2        200000
# 3        168966
# 4         91901
#           ...
# 19232    300000
# 19233    161600
# 19234    116365
# 19235     51258
# 19236    186923
# ...

# %% [markdown]
# *La variable Mileage tiene la indicacion km, eliminamos esta etiqueta y transformamos la variable en entero.*

# %%
# Correccion de la variable Doors
# Cambia 04-May por 4-5
dataset['Doors']= dataset['Doors'].str.replace('04-May','4-5')
# Cambia 02-Mar por 2-3
dataset['Doors']= dataset['Doors'].str.replace('02-Mar','2-3')
dataset['Doors']
# Out:
# <ipython-input-19-5ea229ae42f1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Doors']= dataset['Doors'].str.replace('04-May','4-5')
# <ipython-input-19-5ea229ae42f1>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Doors']= dataset['Doors'].str.replace('02-Mar','2-3')
# 0        4-5
# 1        4-5
# 2        4-5
# 3        4-5
# 4        4-5
#         ...
# 19232    2-3
# 19233    4-5
# 19234    4-5
# 19235    4-5
# 19236    4-5
# ...

# %% [markdown]
# *La variable Doors tidentifico los datos como si fueran fechas, se realiza la correccion para indicar que son una variable objeto.*

# %%
# Se agrega la columna Age (Edad del automovil en Años)
dtime = dt.datetime.now()
dataset['Age']=dtime.year - dataset['Prod. year']
dataset['Age']
# Out:
# <ipython-input-20-8a1053e49550>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Age']=dtime.year - dataset['Prod. year']
# 0        14
# 1        13
# 2        18
# 3        13
# 4        10
#          ..
# 19232    25
# 19233    13
# 19234    14
# 19235    17
# 19236    12
# Name: Age, Length: 18924, dtype: int64

# %% [markdown]
# *Se genera una nueva columna llamada Age para determinar la edad de antiguedad del vehiculo.*

# %%
#Informacion de Dataset con los ajustes realizados
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18924 entries, 0 to 19236
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18924 non-null  int64
#  1   Price             18924 non-null  int64
#  2   Levy              18924 non-null  int64
#  3   Manufacturer      18924 non-null  object
#  4   Model             18924 non-null  object
#  5   Prod. year        18924 non-null  int64
#  6   Category          18924 non-null  object
#  7   Leather interior  18924 non-null  object
#  8   Fuel type         18924 non-null  object
#  9   Engine volume     18924 non-null  float64
#  10  Mileage           18924 non-null  int64
#  11  Cylinders         18924 non-null  float64
#  12  Gear box type     18924 non-null  object
#  13  Drive wheels      18924 non-null  object
#  14  Doors             18924 non-null  object
#  15  Wheel             18924 non-null  object
# ...

# %% [markdown]
# Diccionarios de las columnas nuevas
# - Turbo: indica si el volumen del motor es version turbo.
# - Age: indica la cantidad de años del vehiculo desde su produccion hasta el presente.

# %% [markdown]
# ### **Valores outliers**

# %%
#Indicamos el tamaño de los gráficos
plt.figure(figsize=(20, 20))

#Corremos un ciclo for para ir graficando cada una de las variables float e int
for i, column in enumerate(dataset.select_dtypes(include=['float64', 'int64']).columns):
    plt.subplot(6, 3, i + 1)
    sns.boxplot(x=dataset[column])
    plt.title(column)
    plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
# Hacemos el calculo de los outliers
data_numeric=dataset.select_dtypes(include=['number'])
for col in data_numeric:
    q1=data_numeric[col].quantile(0.25)
    q3=data_numeric[col].quantile(0.75)
    iqr=q3-q1
    low=q1-1.5*iqr
    high=q3+1.5*iqr
    outlier=((data_numeric[col]>high)|(data_numeric[col]<low)).sum()
    total=data_numeric[col].shape[0]
    print (f'Outliers totales en {col} son:{outlier} = {round(100*(outlier)/total,2)}%')
    if outlier>0:
        data=dataset.loc[(dataset[col]<=high) & (dataset[col]>=low)]
# Out:
# Outliers totales en ID son:2460 = 13.0%
# Outliers totales en Price son:1055 = 5.57%
# Outliers totales en Levy son:160 = 0.85%
# Outliers totales en Prod. year son:962 = 5.08%
# Outliers totales en Engine volume son:1358 = 7.18%
# Outliers totales en Mileage son:635 = 3.36%
# Outliers totales en Cylinders son:4765 = 25.18%
# Outliers totales en Airbags son:0 = 0.0%
# Outliers totales en Age son:962 = 5.08%

# %% [markdown]
# *Se grafican y se calculan para ver los valores de outliers de las variables cuantitativas, para identificar estos y en caso de ser necesario tomar las medidas correspondientes.*

# %% [markdown]
# ## **EDA: Análisis Exploratorio de datos**

# %% [markdown]
# ### **Análisis univariado**

# %%
# Graficamos el top 10 de marcas de vehiculos
top_10_cars=dataset['Manufacturer'].value_counts().sort_values(ascending=False).head(10)
sns.barplot(data=top_10_cars)
plt.xticks(rotation=60, ha="right")
plt.title('Top 10 de marcas de autos vendidos')
plt.show()

# %% [markdown]
# *Se grafica el top 10 de las marcas que vendieron mayor cantidad de autos.*

# %%
# Graficamos el top 10 de modelos de vehiculos
top_10_cars=dataset['Model'].value_counts().sort_values(ascending=False).head(10)
sns.barplot(data=top_10_cars)
plt.xticks(rotation=60, ha="right")
plt.title('Top 10 modelos mas vendidos')
plt.show()

# %% [markdown]
# *Se grafica el top 10 de los modelos que vendieron mayor cantidad de autos.*

# %%
# Graficamos la variables categoricas ['Category' , 'Color' , 'Drive wheels', 'Gear box type', 'Fuel type' , 'Turbo', 'Wheel', 'Leather interior']
columns = ['Category' , 'Color' , 'Drive wheels', 'Gear box type', 'Fuel type' , 'Turbo', 'Wheel', 'Leather interior']
for column in columns:
    sns.countplot(data=dataset, x=column ,order=dataset[column].value_counts().index)
    plt.xticks(rotation=60, ha="right")
    plt.title(column)
    plt.show()

# %% [markdown]
# *Se grafican las principales variables para ver como se comportan las cantidades de vehiculos segmentados en las variables cualitativas de la muestra y observar si alguna de las segmentaciones no es relevante.*

# %%
#Histograma de frecuencia de las variables cuantitativas
fig, axs = plt.subplots(2, 3, figsize=(20,15))

#Fila 0 de gráficos
axs[0,0].hist(dataset['Levy'], bins=100)
axs[0,0].set_title('Histograma de impuesto al costo del automovil', fontsize=12)
axs[0,0].set_xlabel('Impuesto (Levy)', fontsize=12)
axs[0,0].set_ylabel('Frecuencia', fontsize=12)
axs[0,1].hist(dataset['Engine volume'], bins=100)
axs[0,1].set_title('Histograma del volumen del motor del automovil', fontsize=12)
axs[0,1].set_xlabel('Volumen del motor', fontsize=12)
axs[0,1].set_ylabel('Frecuencia', fontsize=12)
axs[0,2].hist(dataset['Cylinders'], bins=100)
axs[0,2].set_title('Histograma de la cantidad de cilindros del motor del automovil', fontsize=12)
axs[0,2].set_xlabel('Cantidad de cilindros', fontsize=12)
axs[0,2].set_ylabel('Frecuencia', fontsize=12)

#Fila 1 de gráficos
axs[1,0].hist(dataset['Airbags'], bins=100)
axs[1,0].set_title('Histograma de la cantidad de airbags del automovil', fontsize=12)
axs[1,0].set_xlabel('Cantidad de airbags', fontsize=12)
axs[1,0].set_ylabel('Frecuencia', fontsize=12)
axs[1,1].hist(dataset['Prod. year'], bins=100)
axs[1,1].set_title('Histograma del año de fabricacion del automovil', fontsize=12)
axs[1,1].set_xlabel('Año de fabricacion', fontsize=12)
axs[1,1].set_ylabel('Frecuencia', fontsize=12)
axs[1,2].hist(dataset['Age'], bins=100)
axs[1,2].set_title('Histograma de cantidad año del automovil', fontsize=12)
axs[1,2].set_xlabel('Edad del automovil', fontsize=12)
axs[1,2].set_ylabel('Frecuencia', fontsize=12)


plt.tight_layout()
plt.show()

# %% [markdown]
# *Se grafican los histogramas para ver la frecuencia en que se repiten los casos de las diversas variables cuantitativas de la muestra.*

# %% [markdown]
# ### **Análisis bivariado**

# %%
# Gráfico de barras de la sumatoria del precio de los autos segmentados por las diferentes variables

#Gráficos de barras
fig, axs = plt.subplots(figsize=(25,15))

#Fila 0 de gráficos
price_total = dataset[["Manufacturer","Price"]].groupby("Manufacturer").sum() #Sumatoria del valor del precio segmentado por variable
price_total = price_total.sort_values(by='Price', ascending=False).head(15)
sns.barplot(data=price_total, x="Manufacturer", y="Price", ax = axs)
axs.set_title('Sumatoria del precio de los automoviles del mercado por fabricante', fontsize=12)
axs.set_xlabel('Fabricantes', fontsize=12)
axs.set_ylabel('Precio en USD', fontsize=12)
axs.ticklabel_format(useOffset=False, style='plain', axis='y')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-28-7cf51f77ff2b>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)

# %%
# Gráfico de barras de la sumatoria del precio de los autos segmentados por las diferentes variables

#Gráficos de barras
fig, axs = plt.subplots(figsize=(25,15))

#Fila 0 de gráficos
price_total = dataset[["Model","Price"]].groupby("Model").sum() #Sumatoria del valor del precio segmentado por variable
price_total = price_total.sort_values(by='Price', ascending=False).head(15)
sns.barplot(data=price_total, x="Model", y="Price", ax = axs)
axs.set_title('Sumatoria del precio de los automoviles del mercado por modelo', fontsize=12)
axs.set_xlabel('Modelos', fontsize=12)
axs.set_ylabel('Precio en USD', fontsize=12)
axs.ticklabel_format(useOffset=False, style='plain', axis='y')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-29-0c856d3b73f6>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)

# %%
# Gráfico de barras de la sumatoria del precio de los autos segmentados por las diferentes variables

#Gráficos de barras
fig, axs = plt.subplots(figsize=(25,15))

#Fila 0 de gráficos
price_total = dataset[["Category","Price"]].groupby("Category").sum() #Sumatoria del valor del precio segmentado por variable
price_total = price_total.sort_values(by='Price', ascending=False).head(15)
sns.barplot(data=price_total, x="Category", y="Price", ax = axs)
axs.set_title('Sumatoria del precio de los automoviles del mercado por categoria', fontsize=12)
axs.set_xlabel('Modelos', fontsize=12)
axs.set_ylabel('Precio en USD', fontsize=12)
axs.ticklabel_format(useOffset=False, style='plain', axis='y')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-30-14d70a26713f>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)

# %%
# Gráfico de barras de la sumatoria del precio de los autos segmentados por las diferentes variables

#Gráficos de barras
fig, axs = plt.subplots(figsize=(25,15))

#Fila 0 de gráficos
price_total = dataset[["Fuel type","Price"]].groupby("Fuel type").sum() #Sumatoria del valor del precio segmentado por variable
price_total = price_total.sort_values(by='Price', ascending=False).head(15)
sns.barplot(data=price_total, x="Fuel type", y="Price", ax = axs)
axs.set_title('Sumatoria del precio de los automoviles del mercado por tipo de combustible', fontsize=12)
axs.set_xlabel('Tipo de Combustible', fontsize=12)
axs.set_ylabel('Precio en USD', fontsize=12)
axs.ticklabel_format(useOffset=False, style='plain', axis='y')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-31-ac03b3057cfd>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)

# %%
# Gráfico de barras de la sumatoria del precio de los autos segmentados por las diferentes variables
#Gráficos de barras
fig, axs = plt.subplots(figsize=(25,15))

#Fila 0 de gráficos
price_total = dataset[["Gear box type","Price"]].groupby("Gear box type").sum() #Sumatoria del valor del precio segmentado por variable
price_total = price_total.sort_values(by='Price', ascending=False).head(15)
sns.barplot(data=price_total, x="Gear box type", y="Price", ax = axs)
axs.set_title('Sumatoria del precio de los automoviles del mercado por tipo de transmision', fontsize=12)
axs.set_xlabel('Tipo de Transmision', fontsize=12)
axs.set_ylabel('Precio en USD', fontsize=12)
axs.ticklabel_format(useOffset=False, style='plain', axis='y')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-32-83066348d4aa>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)

# %%
# Gráfico de barras de la sumatoria del precio de los autos segmentados por las diferentes variables

#Gráficos de barras
fig, axs = plt.subplots(figsize=(25,15))

#Fila 0 de gráficos
price_total = dataset[["Drive wheels","Price"]].groupby("Drive wheels").sum() #Sumatoria del valor del precio segmentado por variable
price_total = price_total.sort_values(by='Price', ascending=False).head(15)
sns.barplot(data=price_total, x="Drive wheels", y="Price", ax = axs)
axs.set_title('Sumatoria del precio de los automoviles del mercado por tipo de traccion', fontsize=12)
axs.set_xlabel('Tipo de Traccion', fontsize=12)
axs.set_ylabel('Precio en USD', fontsize=12)
axs.ticklabel_format(useOffset=False, style='plain', axis='y')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-33-f032a28a0af8>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)

# %%
# Gráfico de barras de la sumatoria del precio de los autos segmentados por las diferentes variables

#Gráficos de barras
fig, axs = plt.subplots(figsize=(25,15))

#Fila 0 de gráficos
price_total = dataset[["Doors","Price"]].groupby("Doors").sum() #Sumatoria del valor del precio segmentado por variable
price_total = price_total.sort_values(by='Price', ascending=False).head(8)
sns.barplot(data=price_total, x="Doors", y="Price", ax = axs)
axs.set_title('Sumatoria del precio de los automoviles del mercado por cantidad de puertas', fontsize=12)
axs.set_xlabel('Cantidad de puertas', fontsize=12)
axs.set_ylabel('Precio en USD', fontsize=12)
axs.ticklabel_format(useOffset=False, style='plain', axis='y')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-34-6bceacede34c>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)

# %%
# Gráfico de barras de la sumatoria del precio de los autos segmentados por las diferentes variables

#Gráficos de barras
fig, axs = plt.subplots(figsize=(25,15))

#Fila 0 de gráficos
price_total = dataset[["Wheel", "Price"]].groupby("Wheel").sum() #Sumatoria del valor del precio segmentado por variable
price_total = price_total.sort_values(by='Price', ascending=False).head(15)
sns.barplot(data=price_total, x="Wheel", y="Price", ax = axs)
axs.set_title('Sumatoria del precio de los automoviles por ubicacion del volante', fontsize=12)
axs.set_xlabel('Ubicacion del volante', fontsize=12)
axs.set_ylabel('Precio en USD', fontsize=12)
axs.ticklabel_format(useOffset=False, style='plain', axis='y')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-35-1bc3d506290f>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)

# %%
# Gráfico de barras de la sumatoria del precio de los autos segmentados por las diferentes variables

#Gráficos de barras
fig, axs = plt.subplots(figsize=(25,15))

#Fila 0 de gráficos
price_total = dataset[["Color", "Price"]].groupby("Color").sum() #Sumatoria del valor del precio segmentado por variable
price_total = price_total.sort_values(by='Price', ascending=False).head(15)
sns.barplot(data=price_total, x="Color", y="Price", ax = axs)
axs.set_title('Sumatoria del precio de los automoviles del mercado por color', fontsize=12)
axs.set_xlabel('Color', fontsize=12)
axs.set_ylabel('Precio en USD', fontsize=12)
axs.ticklabel_format(useOffset=False, style='plain', axis='y')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-36-65d1832fe909>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)

# %%
# Gráfico de barras de la sumatoria del precio de los autos segmentados por las diferentes variables

#Gráficos de barras
fig, axs = plt.subplots(figsize=(25,15))

#Fila 0 de gráficos
price_total = dataset[["Turbo", "Price"]].groupby("Turbo").sum() #Sumatoria del valor del precio segmentado por variable
price_total = price_total.sort_values(by='Price', ascending=False).head(15)
sns.barplot(data=price_total, x="Turbo", y="Price", ax = axs)
axs.set_title('Sumatoria del precio de los automoviles version turbo', fontsize=12)
axs.set_xlabel('Turbo', fontsize=12)
axs.set_ylabel('Precio en USD', fontsize=12)
axs.ticklabel_format(useOffset=False, style='plain', axis='y')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-37-9c3b2c70b093>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)

# %% [markdown]
# *Se realizaron los gráficos de barra para poder observar la sumatoria del precio de los automoviles segmentados por las variables cualitativas y así poder determinar si alguna de estas concentra la mayor cantidad de valor en usd, lo cual nos podria servir para enfocarenos en el modelo.*

# %%
# Gráfico de barras del promedeio del precio de los autos segmentados por las diferentes variables

#Gráficos de barras
fig, axs = plt.subplots(figsize=(25,15))

#Fila 0 de gráficos
average_prices = dataset[["Manufacturer","Price"]].groupby("Manufacturer").mean() #Promedio del valor del precio segmentado por variable
average_prices = average_prices.sort_values(by='Price', ascending=False).head(15)
sns.barplot(data=average_prices, x="Manufacturer", y="Price", ax = axs)
axs.set_title('Precio promedio de los automoviles del mercado por fabricante', fontsize=12)
axs.set_xlabel('Fabricantes', fontsize=12)
axs.set_ylabel('Precio en USD', fontsize=12)
axs.ticklabel_format(useOffset=False, style='plain', axis='y')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-38-d4d3e4edc549>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)

# %%
# Gráfico de barras del promedeio del precio de los autos segmentados por las diferentes variables

#Gráficos de barras
fig, axs = plt.subplots(figsize=(25,15))

#Fila 0 de gráficos
average_prices = dataset[["Model","Price"]].groupby("Model").mean() #Promedio del valor del precio segmentado por variable
average_prices = average_prices.sort_values(by='Price', ascending=False).head(15)
sns.barplot(data=average_prices, x="Model", y="Price", ax = axs)
axs.set_title('Precio promedio de los automoviles del mercado por modelo', fontsize=12)
axs.set_xlabel('Modelos', fontsize=12)
axs.set_ylabel('Precio en USD', fontsize=12)
axs.ticklabel_format(useOffset=False, style='plain', axis='y')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=8)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-39-235aadc43379>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=8)

# %%
# Gráfico de barras del promedeio del precio de los autos segmentados por las diferentes variables

#Gráficos de barras
fig, axs = plt.subplots(figsize=(25,15))

#Fila 0 de gráficos
average_prices = dataset[["Category","Price"]].groupby("Category").mean() #Promedio del valor del precio segmentado por variable
average_prices = average_prices.sort_values(by='Price', ascending=False).head(15)
sns.barplot(data=average_prices, x="Category", y="Price", ax = axs)
axs.set_title('Precio promedio de los automoviles del mercado por categoria', fontsize=12)
axs.set_xlabel('Categoria', fontsize=12)
axs.set_ylabel('Precio en USD', fontsize=12)
axs.ticklabel_format(useOffset=False, style='plain', axis='y')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-40-29ee28c50d5f>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)

# %%
# Gráfico de barras del promedeio del precio de los autos segmentados por las diferentes variables

#Gráficos de barras
fig, axs = plt.subplots(figsize=(25,15))

#Fila 0 de gráficos
average_prices = dataset[["Fuel type","Price"]].groupby("Fuel type").mean() #Promedio del valor del precio segmentado por variable
average_prices = average_prices.sort_values(by='Price', ascending=False).head(15)
sns.barplot(data=average_prices, x="Fuel type", y="Price", ax = axs)
axs.set_title('Precio promedio de los automoviles del mercado por tipo de combustible', fontsize=12)
axs.set_xlabel('Tipo de combustible', fontsize=12)
axs.set_ylabel('Precio en USD', fontsize=12)
axs.ticklabel_format(useOffset=False, style='plain', axis='y')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-41-10605b429bbb>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)

# %%
# Gráfico de barras del promedeio del precio de los autos segmentados por las diferentes variables

#Gráficos de barras
fig, axs = plt.subplots(figsize=(25,15))

#Fila 0 de gráficos
average_prices = dataset[["Gear box type","Price"]].groupby("Gear box type").mean() #Promedio del valor del precio segmentado por variable
average_prices = average_prices.sort_values(by='Price', ascending=False).head(15)
sns.barplot(data=average_prices, x="Gear box type", y="Price", ax = axs)
axs.set_title('Precio promedio de los automoviles del mercado por tipo de transmision', fontsize=12)
axs.set_xlabel('Tipo de transmision', fontsize=12)
axs.set_ylabel('Precio en USD', fontsize=12)
axs.ticklabel_format(useOffset=False, style='plain', axis='y')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-42-f269d36aa34e>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)

# %%
# Gráfico de barras del promedeio del precio de los autos segmentados por las diferentes variables

#Gráficos de barras
fig, axs = plt.subplots(figsize=(25,15))

#Fila 0 de gráficos
average_prices = dataset[["Drive wheels","Price"]].groupby("Drive wheels").mean() #Promedio del valor del precio segmentado por variable
average_prices = average_prices.sort_values(by='Price', ascending=False).head(15)
sns.barplot(data=average_prices, x="Drive wheels", y="Price", ax = axs)
axs.set_title('Precio promedio de los automoviles del mercado por tipo de traccion', fontsize=12)
axs.set_xlabel('Tipo de traccion', fontsize=12)
axs.set_ylabel('Precio en USD', fontsize=12)
axs.ticklabel_format(useOffset=False, style='plain', axis='y')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-43-369e514af235>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)

# %%
# Gráfico de barras del promedeio precio de los autos segmentados por las diferentes variables

#Gráficos de barras
fig, axs = plt.subplots(figsize=(25,15))

#Fila 0 de gráficos
average_prices = dataset[["Doors","Price"]].groupby("Doors").mean() #Promedio del valor del precio segmentado por variable
average_prices = average_prices.sort_values(by='Price', ascending=False).head(15)
sns.barplot(data=average_prices, x="Doors", y="Price", ax = axs)
axs.set_title('Precio promedio de los automoviles del mercado por cantidad de puertas', fontsize=12)
axs.set_xlabel('Cantidad de puertas', fontsize=12)
axs.set_ylabel('Precio en USD', fontsize=12)
axs.ticklabel_format(useOffset=False, style='plain', axis='y')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-44-42b2fc6a405f>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)

# %%
# Gráfico de barras del promedeio precio de los autos segmentados por las diferentes variables

#Gráficos de barras
fig, axs = plt.subplots(figsize=(25,15))

#Fila 0 de gráficos
average_prices = dataset[["Wheel","Price"]].groupby("Wheel").mean() #Promedio del valor del precio segmentado por variable
average_prices = average_prices.sort_values(by='Price', ascending=False).head(15)
sns.barplot(data=average_prices, x="Wheel", y="Price", ax = axs)
axs.set_title('Precio promedio de los automoviles del mercado por posicion del volante', fontsize=12)
axs.set_xlabel('Posicion del volante', fontsize=12)
axs.set_ylabel('Precio en USD', fontsize=12)
axs.ticklabel_format(useOffset=False, style='plain', axis='y')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-45-d76244281e8f>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)

# %%
# Gráfico de barras del promedeio del precio de los autos segmentados por las diferentes variables

#Gráficos de barras
fig, axs = plt.subplots(figsize=(25,15))

#Fila 0 de gráficos
average_prices = dataset[["Color","Price"]].groupby("Color").mean() #Promedio del valor del precio segmentado por variable
average_prices = average_prices.sort_values(by='Price', ascending=False).head(15)
sns.barplot(data=average_prices, x="Color", y="Price", ax = axs)
axs.set_title('Precio promedio de los automoviles del mercado por color', fontsize=12)
axs.set_xlabel('Color', fontsize=12)
axs.set_ylabel('Precio en USD', fontsize=12)
axs.ticklabel_format(useOffset=False, style='plain', axis='y')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-46-b0701312fa9d>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)

# %%
# Gráfico de barras del promedeio precio de los autos segmentados por las diferentes variables

#Gráficos de barras
fig, axs = plt.subplots(figsize=(25,15))

#Fila 0 de gráficos
average_prices = dataset[["Turbo","Price"]].groupby("Turbo").mean() #Promedio del valor del precio segmentado por variable
average_prices = average_prices.sort_values(by='Price', ascending=False).head(15)
sns.barplot(data=average_prices, x="Turbo", y="Price", ax = axs)
axs.set_title('Precio promedio de los automoviles del mercado por version del motor turbo', fontsize=12)
axs.set_xlabel('Version Turbo', fontsize=12)
axs.set_ylabel('Precio en USD', fontsize=12)
axs.ticklabel_format(useOffset=False, style='plain', axis='y')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-47-b42acb4cfb41>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=12)

# %% [markdown]
# *Se realizaron los gráficos de barra para poder observar los valores promedios del precio de los automoviles segmentados por las variables cualitativas y así poder determinar si alguna de estas concentra la mayor cantidad de valor en usd, lo cual nos podria servir para enfocarenos en el modelo.*

# %%
#Gráficos de puntos del precio vs las diferentes variables cuantitativas del dataset

#Gráficos de puntos
fig, axs = plt.subplots(2, 3, figsize=(20,15))

#Fila 0 de gráficos
sns.scatterplot(data=dataset, x="Levy", y="Price", ax = axs[0,0])
axs[0,0].set_title('Precio vs. Impuesto', fontsize=12)
axs[0,0].set_xlabel('USD', fontsize=12)
axs[0,0].set_ylabel('USD', fontsize=12)
sns.scatterplot(data=dataset, x="Engine volume", y="Price", ax = axs[0,1])
axs[0,1].set_title('Precio vs. Motor', fontsize=12)
axs[0,1].set_xlabel('Motor', fontsize=12)
axs[0,1].set_ylabel('USD', fontsize=12)
sns.scatterplot(data=dataset, x="Mileage", y="Price", ax = axs[0,2])
axs[0,2].set_title('Precio vs. Kilometraje', fontsize=12)
axs[0,2].set_xlabel('KM', fontsize=12)
axs[0,2].set_ylabel('USD', fontsize=12)

#Fila 1 de gráficos
sns.scatterplot(data=dataset, x="Cylinders", y="Price", ax = axs[1,0])
axs[1,0].set_title('Precio vs. Cilindros', fontsize=12)
axs[1,0].set_xlabel('Cilindros', fontsize=12)
axs[1,0].set_ylabel('USD', fontsize=12)
sns.scatterplot(data=dataset, x="Airbags", y="Price", ax = axs[1,1])
axs[1,1].set_title('Precio vs. Airbags', fontsize=12)
axs[1,1].set_xlabel('Airbags', fontsize=12)
axs[1,1].set_ylabel('USD', fontsize=12)
sns.scatterplot(data=dataset, x="Age", y="Price", ax = axs[1,2])
axs[1,2].set_title('Precio vs. Edad del Vehiculo', fontsize=12)
axs[1,2].set_xlabel('Edad', fontsize=12)
axs[1,2].set_ylabel('USD', fontsize=12)


plt.tight_layout()
plt.show()

# %% [markdown]
# *Se graficaron las variables cuantitativas para observar su respectiva relación con el precio de valoración de los automoviles, todo esto con la idea de detectar algún patrón que nos indicara si una de estas variables tiene relación con nuestra variable objetivo, lamentablemente los gráficos no nos indican una relación directa de ninguna de estas variables con el precio.*

# %% [markdown]
# ### **Análisis multivariado**

# %%
# Selecciona solo las variables float e int
dataset = dataset.drop('ID', axis=1)
cuantitative_var = dataset.select_dtypes(include=['float64', 'int64']).columns

# Cálculo de la correlación
correlation_matrix = dataset[cuantitative_var].corr()

#Gráfica el mapa de calor
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm',annot_kws={"size": 8}, fmt='.3f')
plt.title('Matriz de Correlación')
plt.show()

# %% [markdown]
# *Graficamos una matriz de correlación de todas las variables cuantitativas, este nos indica los valores de correlación con nuestra variable objetivo en este caso estos valores son muy cercanos a 0 indicándonos que no existe una relación lineal.*
